# %% [markdown]
# # Factorial

# %% [markdown]
# ##  Dada una entrada ‘a’, imprimir el factorial de ‘a’.

# %%
a = 5
fac = 1
if a != 0:
    for i in range(1,a+1):
        fac = fac *i 
print("El factorial es:",fac)
# Out:
# El factorial es: 120

# %% [markdown]
# ![imagen_DF](![Captura de pantalla 2024-08-16 235637.png](attachment:aac2d3e1-904d-4eab-868a-0ed729eb82b9.png))

# %% [markdown]
# #  Números primos

# %% [markdown]
# ## Dada una entrada ‘a’, imprimir si ‘a’ es un número primo.

# %%
a = 2
if a <= 1:
    print("No es numero primo")
else: 
    primo = True
    for i in range(2, a):
        if a % i == 0:
            primo = False
            break
    if primo:
        print(" es un número primo.")
    else:
        print(" no es un número primo.")
# Out:
#  es un número primo.

# %% [markdown]
# ![imagen_DF1](![Captura de pantalla 2024-08-16 235637.png](attachment:aac2d3e1-904d-4eab-868a-0ed729eb82b9.png))
