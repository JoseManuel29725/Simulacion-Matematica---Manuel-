# %% [markdown]
# Jose Manuel Orozco Martinez
# 27/08/2024
# ## 1. Graficar las siguientes funciones f(x). Determina el dominio a partir de la función:

# %%
import numpy as np
import matplotlib.pyplot as plt

x = np.linspace(-2, 6, 300)  
y = x**2 - 4*x + 2

# Graficar la función
plt.figure(figsize=(8, 6))
plt.plot(x, y,label="$f(x) = x^2 - 4x + 2$" )
plt.title(" $función f(x) =x^2 - 4x + 2$")
plt.xlabel("x")
plt.ylabel("y=f(x)")
plt.grid()
plt.legend() # este activa la funcion en el grafico

# %% [markdown]
# EL dominio de la funcion son todos los numeros reales va de (-∞ ,∞) ya que es un polinomio.

# %%
import numpy as np
import matplotlib.pyplot as plt

x = np.linspace(-2, 6, 300)  
y = np.sin(3*x)

# Graficar la función
plt.figure(figsize=(8, 6))
plt.plot(x, y, label="$=sin(3x)$")
plt.title(" $función f(x) =sin(3x)$")
plt.xlabel("x")
plt.ylabel("y=f(x)")
plt.grid()
plt.legend()

# %% [markdown]
# Dominio de sin(3x) son todos los numeros reales.
# es el mismo que el dominio de la función seno básica, ya que la multiplicación
# del argumento por una constante no cambia el conjunto de valores para los cuales la función está definida

# %%
import numpy as np
import matplotlib.pyplot as plt

x = np.linspace(-2, 6, 300)  
y = np.exp(2*x-3)

# Graficar la función
plt.figure(figsize=(8, 6))
plt.plot(x, y, label="$e^{2x}-3$")
plt.title(" función f(x) =$e^{2x}-3$")
plt.xlabel("x")
plt.ylabel("y=f(x)")
plt.grid()
plt.legend()

# %% [markdown]
# El rango puede ser:(-2,6) pero el dominio tambien son todos los numeros reales. la transformación lineal 2x-3 no
# impone ninguna restriccion (-∞ ,∞)

# %%
import numpy as np
import matplotlib.pyplot as plt
def f(x):
    return np.sqrt(x**2 - 4)

x1 = np.linspace(-4, -2, 300)  
x2 = np.linspace(2, 4, 300)    

y1 =f(x1)
y2 =f(x2)

# Graficar la función
plt.figure(figsize=(8, 6))
plt.plot(x1, y1, label=r"f(x) = $√x^2-4$ ", color='green')
plt.plot(x2, y2, color='green')
plt.title(" función f(x) = $√x^2-4$")
plt.xlabel("x")
plt.ylabel("y=f(x)")
plt.grid()
plt.legend()

# %% [markdown]
# El dominio es: (−∞,−2]∪[2,∞), ya que la grafica se ve que termina

# %%
import numpy as np
import matplotlib.pyplot as plt

x = np.linspace(-2, 6, 300)  
y = np.cos(x+ np.pi/4)

# Graficar la función
plt.figure(figsize=(8, 6))
plt.plot(x, y, label="cos(x+π/4)")
plt.title(" función f(x) =cos(x+π/4)")
plt.xlabel("x")
plt.ylabel("y=f(x)")
plt.grid()
plt.legend()

# %% [markdown]
# De igual manera son todos los numeros reales (-∞ ,∞)

# %% [markdown]
# ## 2. Graficar los siguientes grupos de funciones:
# ### Grupo 1

# %%
import numpy as np
import matplotlib.pyplot as plt

x1 = np.linspace(-2, 6, 300)  
x2 = np.linspace(-2, 6, 300)    
x3 = np.linspace(-2, 6, 300) 
y1 = 2*x +1
y2 = -x+4
y3 = x**2
# Graficar la función
plt.figure(figsize=(10, 7))
plt.plot(x1, y1, label= "f(x) = $2x+1$ ", color='green')
plt.plot(x2, y2,label = "f(x) = $-x+4$",  color='red')
plt.plot(x3 , y3,label = "f(x) = $x^2$", color = 'yellow')
plt.title(" grupo de funciones ")
plt.xlabel("x")
plt.ylabel("y")
plt.grid()
plt.legend()

# %% [markdown]
# ### Grupo 2

# %%
import numpy as np
import matplotlib.pyplot as plt


x = np.linspace(-2 * np.pi, 2 * np.pi, 400)
   
y1 = np.sin(x)
y2 = np.cos(x)
#graficar la funcion

plt.figure(figsize=(10,7))
plt.plot(x, y1, label=r"f(x) = $sin(x)$ ", color='green')
plt.plot(x, y2, label="f(x)= $cos(x)$",color='red')
plt.title(" grupo de funciones ")
plt.xlabel("x")
plt.ylabel("y")
plt.grid()
plt.legend()

# %% [markdown]
# ## 3. Crea una función que cree una gráfica y dibuje 'k' líneas

# %%
import numpy as np
import matplotlib.pyplot as plt

def plot_sin_lines(x1, x2, n, a, b, k):
    
    
    x = np.linspace(x1, x2, n)
    valores_alpha = np.linspace(a, b, k)
    
    # Crear la gráfica
    plt.figure(figsize=(10, 6))
     # Graficar cada línea
    for alpha in valores_alpha:
        y = np.sin(alpha * x)
        plt.plot(x, y, label=f'α = {alpha:.2f}')  # Etiqueta con valor de α
        
    plt.title('Gráfico de f(x) = sin(αx) ')
    plt.xlabel('x')
    plt.ylabel('y')
    plt.legend()
    plt.grid()
    plt.show()

# Ejemplo de uso
plot_sin_lines(x1=0, x2=2, n=300, a=2, b=4, k=3)

# %% [markdown]
# $\cos\left(x + \frac{\pi}{4}\right)$
